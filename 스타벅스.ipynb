# %%
! pip install selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
browser = webdriver.Chrome('chromedriver.exe')
url = 'https://www.starbucks.co.kr/store/store_map.do'
browser.get(url)
# Out:
# <ipython-input-3-4a7c5fc377b4>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')

# %%
area_btn = '#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a'
browser.find_element_by_css_selector(area_btn).click()
# Out:
# <ipython-input-4-d6df5038dcf3>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_css_selector(area_btn).click()

# %%
seoul_btn ='#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a'
browser.find_element_by_css_selector(seoul_btn).click()
# Out:
# <ipython-input-5-5ad69e805d44>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_css_selector(seoul_btn).click()

# %%
all_btn='#mCSB_2_container > ul > li:nth-child(1) > a'
browser.find_element_by_css_selector(all_btn).click()
# Out:
# <ipython-input-7-45fb08d69b49>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_css_selector(all_btn).click()

# %%
html = browser.page_source
soup = BeautifulSoup(html,'html.parser')

# %%
starbucks_soup_list = soup.select('li.quickResultLstCon')
starbucks_soup_list[0]
# Out:
# <li class="quickResultLstCon" data-code="9626" data-hlytag="null" data-index="0" data-lat="37.5115577" data-long="127.03226199999994" data-name="논현힐탑" data-storecd="430" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="논현힐탑" data-store="430" data-yn="N">논현힐탑  </strong> <p class="result_details">서울특별시 강남구 논현로 648 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
name = starbucks_soup_list[0].select("strong")[0]
#html 태그선택은 select

name
# Out:
# <strong data-my_siren_order_store_yn="N" data-name="논현힐탑" data-store="430" data-yn="N">논현힐탑  </strong>

# %%
name = starbucks_soup_list[0].select("strong")[0].text
#html 태그선택은 select

name
# Out:
# '논현힐탑  '

# %%
name = starbucks_soup_list[0].select("strong")[0].text.strip()
#html 태그선택은 select / strip양쪽 빈칸 날리기

name
# Out:
# '논현힐탑'

# %%
name = starbucks_soup_list[1].select("strong")[0].text.strip()
#html 태그선택은 select

name
# Out:
# '학동역'

# %%
name = starbucks_soup_list[2].select("strong")[0].text.strip()
#html 태그선택은 select

name
# Out:
# '차병원사거리'

# %%
starbucks_soup_list = soup.select('li.quickResultLstCon')
starbucks_soup_list[0]
# Out:
# <li class="quickResultLstCon" data-code="9626" data-hlytag="null" data-index="0" data-lat="37.5115577" data-long="127.03226199999994" data-name="논현힐탑" data-storecd="430" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="논현힐탑" data-store="430" data-yn="N">논현힐탑  </strong> <p class="result_details">서울특별시 강남구 논현로 648 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
starbucks = starbucks_soup_list[0]
lat = starbucks['data-lat']
lat
# Out:
# '37.5115577'

# %%
name = starbucks['data-name']
name
# Out:
# '논현힐탑'

# %%
lng = starbucks['data-long']
lng
# Out:
# '127.03226199999994'

# %%
addr = starbucks.select('p')[0].text.strip()
addr
# Out:
# '서울특별시 강남구 논현로 648 (논현동)1522-3232'

# %%
addr = str(starbucks.select('p')[0]).split('<br/>')[0].split('>')[1]
addr
# Out:
# '서울특별시 강남구 논현로 648 (논현동)'

# %%
tel =  str(starbucks.select('p')[0]).split('<br/>')[1].split('<')[0]
tel
# Out:
# '1522-3232'

# %%
starbucks_list = []
for item in starbucks_soup_list:
    name = item.select("strong")[0].text.strip()
    lat = item['data-lat']
    lng = item['data-long']
    addr = str(item.select('p')[0]).split('<br/>')[0].split('>')[1]
    tel =  str(item.select('p')[0]).split('<br/>')[1].split('<')[0]
    
    starbucks_list.append([name,lat,lng,addr,tel])

# %%
starbucks_list
# Out:
# [['논현힐탑',
#   '37.5115577',
#   '127.03226199999994',
#   '서울특별시 강남구 논현로 648 (논현동)',
#   '1522-3232'],
#  ['학동역', '37.51464884', '127.0307302', '서울특별시 강남구 논현로 704 (논현동)', '1522-3232'],
#  ['차병원사거리',
#   '37.508032',
#   '127.035373',
#   '서울특별시 강남구 봉은사로 213, 센트럴타워 (논현동)',
#   '1522-3232'],
#  ['논현역사거리',
#   '37.510178',
#   '127.022223',
#   '서울특별시 강남구 강남대로 538 (논현동)',
#   '1522-3232'],
#  ['강남대로논현R',
#   '37.507413',
#   '127.022568',
#   '서울특별시 서초구 강남대로85길 5 (반포동)',
#   '1522-3232'],
#  ['서울세관사거리',
#   '37.514887',
#   '127.035653',
#   '서울특별시 강남구 언주로 650 (논현동) 한국건설기술인협회',
#   '1522-3232'],
#  ['논현역',
#   '37.5111983',
#   '127.0205875',
#   '서울특별시 서초구 강남대로 557 (잠원동) 1~2층',
#   '1522-3232'],
#  ['신논현역',
#   '37.50529',
#   '127.023636',
#   '서울특별시 서초구 강남대로 483 (반포동) 청호빌딩',
#   '1522-3232'],
#  ['신사역성일빌딩',
#   '37.514132',
#   '127.020563',
#   '서울특별시 강남구 강남대로 584 (논현동)',
#   '1522-3232'],
#  ['도산가로수길',
#   '37.51736229999999',
#   '127.02329570000006',
# ...

# %%
columns=['매장명','위도','경도','주소','전화번호']
seoul_starbucks_df = pd.DataFrame(starbucks_list, columns=columns)
seoul_starbucks_df
# Out:
#          매장명                 위도                  경도  \
# 0       논현힐탑         37.5115577  127.03226199999994
# 1        학동역        37.51464884         127.0307302
# 2     차병원사거리          37.508032          127.035373
# 3     논현역사거리          37.510178          127.022223
# 4    강남대로논현R          37.507413          127.022568
# ..       ...                ...                 ...
# 572     사가정역          37.579594          127.087966
# 573      상봉역           37.59689           127.08647
# 574    묵동이마트          37.613433          127.077484
# 575       묵동          37.615368          127.076633
# 576      중화역  37.60170912407773  127.07841136432036
#
#                                               주소       전화번호
# 0                        서울특별시 강남구 논현로 648 (논현동)  1522-3232
# 1                        서울특별시 강남구 논현로 704 (논현동)  1522-3232
# 2                서울특별시 강남구 봉은사로 213, 센트럴타워 (논현동)  1522-3232
# 3                       서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# ...

# %%
seoul_starbucks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   매장명     576 non-null    object
#  1   위도      576 non-null    object
#  2   경도      576 non-null    object
#  3   주소      576 non-null    object
#  4   전화번호    576 non-null    object
# dtypes: object(5)
# memory usage: 22.6+ KB

# %%
seoul_starbucks_df.to_excel('seoul_starbucks_list.xlsx',index=False)

# %%
seoul_starbucks = pd.read_excel('seoul_starbucks_list.xlsx', header = 0)

# %%
seoul_starbucks
# Out:
#          매장명         위도          경도  \
# 0       논현힐탑  37.511558  127.032262
# 1        학동역  37.514649  127.030730
# 2     차병원사거리  37.508032  127.035373
# 3     논현역사거리  37.510178  127.022223
# 4    강남대로논현R  37.507413  127.022568
# ..       ...        ...         ...
# 572     사가정역  37.579594  127.087966
# 573      상봉역  37.596890  127.086470
# 574    묵동이마트  37.613433  127.077484
# 575       묵동  37.615368  127.076633
# 576      중화역  37.601709  127.078411
#
#                                               주소       전화번호
# 0                        서울특별시 강남구 논현로 648 (논현동)  1522-3232
# 1                        서울특별시 강남구 논현로 704 (논현동)  1522-3232
# 2                서울특별시 강남구 봉은사로 213, 센트럴타워 (논현동)  1522-3232
# 3                       서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# 4                      서울특별시 서초구 강남대로85길 5 (반포동)  1522-3232
# ..                                           ...        ...
# 572                            서울특별시 중랑구 면목로 310  1522-3232
# ...

# %%
seoul_starbucks['주소']
# Out:
# 0                          서울특별시 강남구 논현로 648 (논현동)
# 1                          서울특별시 강남구 논현로 704 (논현동)
# 2                  서울특별시 강남구 봉은사로 213, 센트럴타워 (논현동)
# 3                         서울특별시 강남구 강남대로 538 (논현동)
# 4                        서울특별시 서초구 강남대로85길 5 (반포동)
#                           ...
# 572                              서울특별시 중랑구 면목로 310
# 573                        서울특별시 중랑구 망우로 307 (상봉동)
# 574    서울특별시 중랑구 동일로 932 (묵동, 묵동자이아파트) (묵동이마트 B1층)
# 575                             서울특별시 중랑구 동일로 952
# 576                         서울특별시 중랑구 봉화산로 35 1,2층
# Name: 주소, Length: 577, dtype: object

# %%
sgg_names = []
for addr in seoul_starbucks['주소']:
    sgg = addr.split()[1]
    sgg_names.append(sgg)
sgg_names
# Out:
# ['강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '서초구',
#  '강남구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강북구',
#  '강북구',
#  '강북구',
# ...

# %%
seoul_starbucks['시군구명'] = sgg_names
seoul_starbucks
# Out:
#          매장명         위도          경도  \
# 0       논현힐탑  37.511558  127.032262
# 1        학동역  37.514649  127.030730
# 2     차병원사거리  37.508032  127.035373
# 3     논현역사거리  37.510178  127.022223
# 4    강남대로논현R  37.507413  127.022568
# ..       ...        ...         ...
# 572     사가정역  37.579594  127.087966
# 573      상봉역  37.596890  127.086470
# 574    묵동이마트  37.613433  127.077484
# 575       묵동  37.615368  127.076633
# 576      중화역  37.601709  127.078411
#
#                                               주소       전화번호 시군구명
# 0                        서울특별시 강남구 논현로 648 (논현동)  1522-3232  강남구
# 1                        서울특별시 강남구 논현로 704 (논현동)  1522-3232  강남구
# 2                서울특별시 강남구 봉은사로 213, 센트럴타워 (논현동)  1522-3232  강남구
# 3                       서울특별시 강남구 강남대로 538 (논현동)  1522-3232  강남구
# 4                      서울특별시 서초구 강남대로85길 5 (반포동)  1522-3232  서초구
# ..                                           ...        ...  ...
# 572                            서울특별시 중랑구 면목로 310  1522-3232  중랑구
# ...

# %%
seoul_starbucks.to_excel('seoul_starbucks_list_sgg.xlsx',index=False)

# %%
seoul_starbucks = pd.read_excel('seoul_starbucks_list_sgg.xlsx', header = 0)

# %%
seoul_starbucks
# Out:
#          매장명         위도          경도  \
# 0       논현힐탑  37.511558  127.032262
# 1        학동역  37.514649  127.030730
# 2     차병원사거리  37.508032  127.035373
# 3     논현역사거리  37.510178  127.022223
# 4    강남대로논현R  37.507413  127.022568
# ..       ...        ...         ...
# 572     사가정역  37.579594  127.087966
# 573      상봉역  37.596890  127.086470
# 574    묵동이마트  37.613433  127.077484
# 575       묵동  37.615368  127.076633
# 576      중화역  37.601709  127.078411
#
#                                               주소       전화번호 시군구명
# 0                        서울특별시 강남구 논현로 648 (논현동)  1522-3232  강남구
# 1                        서울특별시 강남구 논현로 704 (논현동)  1522-3232  강남구
# 2                서울특별시 강남구 봉은사로 213, 센트럴타워 (논현동)  1522-3232  강남구
# 3                       서울특별시 강남구 강남대로 538 (논현동)  1522-3232  강남구
# 4                      서울특별시 서초구 강남대로85길 5 (반포동)  1522-3232  서초구
# ..                                           ...        ...  ...
# 572                            서울특별시 중랑구 면목로 310  1522-3232  중랑구
# ...

# %%
starbucks_sgg_count = seoul_starbucks.pivot_table(
    index = '시군구명',
    values = '주소',
    aggfunc = 'count'
)
starbucks_sgg_count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-317e572fc534> in <module>
# ----> 1 starbucks_sgg_count = seoul_starbucks.pivot_table(
#       2     index = '시군구명',
#       3     values = '주소',
#       4     aggfunc = 'count'
#       5 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    7029         from pandas.core.reshape.pivot import pivot_table
#    7030
# -> 7031         return pivot_table(
#    7032             self,
#    7033             values=values,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     110         values = list(values)
#     111
# ...

# %%
type(starbucks_sgg_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-ce8d79e04a44> in <module>
# ----> 1 type(starbucks_sgg_count)
#
# NameError: name 'starbucks_sgg_count' is not defined

# %%
! pip install folium
# Out:
# ...
#   Using cached folium-0.12.1-py2.py3-none-any.whl (94 kB)
# ...
#   Using cached branca-0.4.2-py3-none-any.whl (24 kB)
# ...

# %%
import pandas as pd
import folium

# %%
starbucks_map = folium.Map(location=[37.53,127],
                           tiles = 'openStreetMap', zoom_start=11)
starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import pandas as pd
seoul_starbucks = pd.read_excel('seoul_starbucks_list.xlsx')

# %%
seoul_starbucks.head()
# Out:
#        매장명         위도          경도                               주소       전화번호
# 0     논현힐탑  37.511558  127.032262          서울특별시 강남구 논현로 648 (논현동)  1522-3232
# 1      학동역  37.514649  127.030730          서울특별시 강남구 논현로 704 (논현동)  1522-3232
# 2   차병원사거리  37.508032  127.035373  서울특별시 강남구 봉은사로 213, 센트럴타워 (논현동)  1522-3232
# 3   논현역사거리  37.510178  127.022223         서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# 4  강남대로논현R  37.507413  127.022568        서울특별시 서초구 강남대로85길 5 (반포동)  1522-3232

# %%
import folium
starbucks_map = folium.Map(location=[37.53,127],
                           tiles = 'Stamen Terrain', zoom_start=11)
starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for idx in seoul_starbucks.index:
    lat = seoul_starbucks.loc[idx, '위도']
    lng = seoul_starbucks.loc[idx, '경도']
    
    folium.Marker(location=[lat,lng]).add_to(starbucks_map)

starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
