# %%
# Tkinter, wxpython, pyqt [자주 사용하는 프로그램]

# %%
import sys
from PyQt5.QtWidgets import *

app = QApplication(sys.argv)

app.exec_()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c130c080a473> in <module>
#       1 import sys
# ----> 2 from PyQt5.QtWidgets import *
#       3
#       4 app = QApplication(sys.argv)
#       5
#
# ModuleNotFoundError: No module named 'PyQt5'

# %%
import pykorbit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-de28951b331a> in <module>
# ----> 1 import pykorbit
#
# ModuleNotFoundError: No module named 'pykorbit'

# %%
! pip install pybithumb
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=9bb10f7d038d606077a16d5f7ee6e7e7b05662eeeb65fce6b349ded6bef7e073
#   Stored in directory: c:\users\itsc\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...

# %%
import pybithumb

# %%
tickers = pybithumb.get_tickers()   #API

# %%
len(tickers)
# Out:
# 180

# %%
price = pybithumb.get_current_price('BTC')
price
# Out:
# 74121000.0

# %%
import time

while True:
    price = pybithumb.get_current_price('BTC')
    print(price)
    time.sleep(3)
# Out:
# 74182000.0
# 74125000.0
# 74136000.0
# 74085000.0
# 74085000.0
# 74054000.0
# 74069000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-46326d2f9751> in <module>
#       4     price = pybithumb.get_current_price('BTC')
#       5     print(price)
# ----> 6     time.sleep(3)
#
# KeyboardInterrupt:

# %%
tickers = pybithumb.get_tickers()

for ticker in tickers:
    price = pybithumb.get_current_price(ticker)
    print(ticker, price)
    time.sleep(1)
# Out:
# BTC 74081000.0
# ETH 5414000.0
# LTC 240800.0
# ETC 64100.0
# XRP 1417.0
# BCH 727000.0
# QTUM 18780.0
# BTG 77050.0
# EOS 5435.0
# ICX 2570.0
# TRX 125.4
# ELF 704.9
# OMG 22230.0
# KNC 2356.0
# GLM 678.3
# ZIL 133.7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2920a026492e> in <module>
#       4     price = pybithumb.get_current_price(ticker)
#       5     print(ticker, price)
# ----> 6     time.sleep(1)
#
# KeyboardInterrupt:

# %%
btc = pybithumb.get_ohlcv('BTC')
btc
# Out:
#                            open        high         low       close  \
# time
# 2013-12-27 00:00:00    737000.0    755000.0    737000.0    755000.0
# 2013-12-28 00:00:00    750000.0    750000.0    750000.0    750000.0
# 2013-12-29 00:00:00    750000.0    750000.0    728000.0    739000.0
# 2013-12-30 00:00:00    740000.0    772000.0    740000.0    768000.0
# 2013-12-31 00:00:00    768000.0    800000.0    763000.0    768000.0
# ...                         ...         ...         ...         ...
# 2021-11-01 00:00:00  72108000.0  73904000.0  71001000.0  73073000.0
# 2021-11-02 00:00:00  73105000.0  75250000.0  71877000.0  74543000.0
# 2021-11-03 00:00:00  74540000.0  75500000.0  72650000.0  72950000.0
# 2021-11-04 00:00:00  72943000.0  74994000.0  72001000.0  74079000.0
# 2021-11-05 20:00:00  74071000.0  74955000.0  73207000.0  74100000.0
#
#                           volume
# time
# 2013-12-27 00:00:00     3.780000
# 2013-12-28 00:00:00    12.000000
# 2013-12-29 00:00:00    19.058000
# ...

# %%
close = btc['close']
print(close)
# Out:
# time
# 2013-12-27 00:00:00      755000.0
# 2013-12-28 00:00:00      750000.0
# 2013-12-29 00:00:00      739000.0
# 2013-12-30 00:00:00      768000.0
# 2013-12-31 00:00:00      768000.0
#                           ...
# 2021-11-01 00:00:00    73073000.0
# 2021-11-02 00:00:00    74543000.0
# 2021-11-03 00:00:00    72950000.0
# 2021-11-04 00:00:00    74079000.0
# 2021-11-05 20:00:00    74100000.0
# Name: close, Length: 2781, dtype: float64

# %%
print((close[0]+close[1]+close[2]+close[3]+close[4])/5)
print((close[1]+close[2]+close[3]+close[4]+close[5])/5)
print((close[2]+close[3]+close[4]+close[5]+close[6])/5)
# Out:
# 756000.0
# 760400.0
# 766000.0

# %%
win = close.rolling(5)  #5일간의 평균
ma5 = win.mean()
print(ma5)
# Out:
# time
# 2013-12-27 00:00:00           NaN
# 2013-12-28 00:00:00           NaN
# 2013-12-29 00:00:00           NaN
# 2013-12-30 00:00:00           NaN
# 2013-12-31 00:00:00      756000.0
#                           ...
# 2021-11-01 00:00:00    73290200.0
# 2021-11-02 00:00:00    73382200.0
# 2021-11-03 00:00:00    73230200.0
# 2021-11-04 00:00:00    73354800.0
# 2021-11-05 20:00:00    73749000.0
# Name: close, Length: 2781, dtype: float64

# %%
ma5 = close.rolling(5).mean()
print(ma5)
# Out:
# time
# 2013-12-27 00:00:00           NaN
# 2013-12-28 00:00:00           NaN
# 2013-12-29 00:00:00           NaN
# 2013-12-30 00:00:00           NaN
# 2013-12-31 00:00:00      756000.0
#                           ...
# 2021-11-01 00:00:00    73290200.0
# 2021-11-02 00:00:00    73382200.0
# 2021-11-03 00:00:00    73230200.0
# 2021-11-04 00:00:00    73354800.0
# 2021-11-05 20:00:00    73749000.0
# Name: close, Length: 2781, dtype: float64

# %%
pip install pykorbit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pykorbit

# %%
tickers = pykorbit.get_tickers()
tickers
# Out:
# ['BTC',
#  'ETH',
#  'ETC',
#  'XRP',
#  'BCH',
#  'LTC',
#  'ZIL',
#  'USDC',
#  'BSV',
#  'OMG',
#  'QTUM',
#  'BAT',
#  'XLM',
#  'AERGO',
#  'FET',
#  'EOS',
#  'MKR',
#  'DAI',
#  'LINK',
#  'BNB',
#  'TRX',
#  'MED',
#  'FIL',
#  'WBTC',
#  'ADA',
#  'UNI',
#  'YFI',
#  'DOT',
#  'ALGO',
#  'XTZ',
#  'ENJ',
#  'SUSHI',
#  'AAVE',
#  'SNX',
#  'MATIC',
#  'FLOW',
#  'FTT',
#  '1INCH',
#  'BAND',
#  'LUNA',
#  'SOL',
#  'KLAY',
#  'GRT',
#  'ATOM',
#  'AMP',
#  'CHZ',
#  'MINA',
#  'COMP',
#  'AXS',
#  'AUDIO',
#  'CRV',
#  'THETA',
#  'RLY',
#  'NU',
#  'OCEAN',
#  'STORJ',
#  'DOGE',
#  'VET',
#  'LRC',
#  'ALPHA',
#  'UMA',
#  'SAND',
#  'ICP',
#  'HNT',
#  'BTT',
#  'XEC',
#  'SGB',
#  'RARI']

# %%
print(len(tickers))
# Out:
# 68

# %%
price = pykorbit.get_current_price('BTC')
print('현재 코빗에서의 비트코인 가격은',price,'입니다.')
price = pybithumb.get_current_price('BTC')
print('현재 빗썸에서의 비트코인 가격은',price,'입니다.')
# Out:
# 현재 코빗에서의 비트코인 가격은 74583000.0 입니다.
# 현재 빗썸에서의 비트코인 가격은 74548000.0 입니다.

# %%
# !pip install ccxt
import ccxt

# %%
import ccxt

# %%
binance = ccxt.binance()

# %%
markets = binance.fetch_tickers()
print(markets.keys())
# Out:
# dict_keys(['ETH/BTC', 'LTC/BTC', 'BNB/BTC', 'NEO/BTC', 'QTUM/ETH', 'EOS/ETH', 'SNT/ETH', 'BNT/ETH', 'BCC/BTC', 'GAS/BTC', 'BNB/ETH', 'BTC/USDT', 'ETH/USDT', 'HSR/BTC', 'OAX/ETH', 'DNT/ETH', 'MCO/ETH', 'ICN/ETH', 'MCO/BTC', 'WTC/BTC', 'WTC/ETH', 'LRC/BTC', 'LRC/ETH', 'QTUM/BTC', 'YOYOW/BTC', 'OMG/BTC', 'OMG/ETH', 'ZRX/BTC', 'ZRX/ETH', 'STRAT/BTC', 'STRAT/ETH', 'SNGLS/BTC', 'SNGLS/ETH', 'BQX/BTC', 'BQX/ETH', 'KNC/BTC', 'KNC/ETH', 'FUN/BTC', 'FUN/ETH', 'SNM/BTC', 'SNM/ETH', 'NEO/ETH', 'IOTA/BTC', 'IOTA/ETH', 'LINK/BTC', 'LINK/ETH', 'XVG/BTC', 'XVG/ETH', 'SALT/BTC', 'SALT/ETH', 'MDA/BTC', 'MDA/ETH', 'MTL/BTC', 'MTL/ETH', 'SUB/BTC', 'SUB/ETH', 'EOS/BTC', 'SNT/BTC', 'ETC/ETH', 'ETC/BTC', 'MTH/BTC', 'MTH/ETH', 'ENG/BTC', 'ENG/ETH', 'DNT/BTC', 'ZEC/BTC', 'ZEC/ETH', 'BNT/BTC', 'AST/BTC', 'AST/ETH', 'DASH/BTC', 'DASH/ETH', 'OAX/BTC', 'ICN/BTC', 'BTG/BTC', 'BTG/ETH', 'EVX/BTC', 'EVX/ETH', 'REQ/BTC', 'REQ/ETH', 'VIB/BTC', 'VIB/ETH', 'HSR/ETH', 'TRX/BTC', 'TRX/ETH', 'POWR/BTC', 'POWR/ETH', 'ARK/B
# ...

# %%
ticker = binance.fetch_ticker('ETH/BTC')
ticker
# Out:
# {'symbol': 'ETH/BTC',
#  'timestamp': 1636112705719,
#  'datetime': '2021-11-05T11:45:05.719Z',
#  'high': 0.073974,
#  'low': 0.072762,
#  'bid': 0.073114,
#  'bidVolume': 5.358,
#  'ask': 0.073123,
#  'askVolume': 2.325,
#  'vwap': 0.07322534,
#  'open': 0.073309,
#  'close': 0.073115,
#  'last': 0.073115,
#  'previousClose': 0.073302,
#  'change': -0.000194,
#  'percentage': -0.265,
#  'average': 0.073212,
#  'baseVolume': 66544.6042,
#  'quoteVolume': 4872.75104447,
#  'info': {'symbol': 'ETHBTC',
#   'priceChange': '-0.00019400',
#   'priceChangePercent': '-0.265',
#   'weightedAvgPrice': '0.07322534',
#   'prevClosePrice': '0.07330200',
#   'lastPrice': '0.07311500',
#   'lastQty': '1.44880000',
#   'bidPrice': '0.07311400',
#   'bidQty': '5.35800000',
#   'askPrice': '0.07312300',
#   'askQty': '2.32500000',
#   'openPrice': '0.07330900',
#   'highPrice': '0.07397400',
#   'lowPrice': '0.07276200',
#   'volume': '66544.60420000',
#   'quoteVolume': '4872.75104447',
# ...

# %%
ohlcvs = binance.fetch_ohlcv('ETH/BTC')
from datetime import datetime
for ohlc in ohlcvs:
    print(datetime.fromtimestamp(ohlc[0]/1000).strftime('%Y-%m-%d'), ohlc)
# Out:
# 2021-11-05 [1636083060000, 0.073196, 0.073231, 0.073196, 0.073226, 32.1204]
# 2021-11-05 [1636083120000, 0.073232, 0.073258, 0.073227, 0.073258, 18.4509]
# 2021-11-05 [1636083180000, 0.073256, 0.073259, 0.073226, 0.073233, 14.9696]
# 2021-11-05 [1636083240000, 0.073233, 0.073235, 0.073201, 0.073202, 13.0744]
# 2021-11-05 [1636083300000, 0.073201, 0.073201, 0.073174, 0.073176, 23.3671]
# 2021-11-05 [1636083360000, 0.073176, 0.07321, 0.073172, 0.073198, 38.4257]
# 2021-11-05 [1636083420000, 0.073197, 0.073197, 0.073174, 0.073189, 44.9948]
# 2021-11-05 [1636083480000, 0.073185, 0.073201, 0.073168, 0.073176, 37.0218]
# 2021-11-05 [1636083540000, 0.073179, 0.073185, 0.073155, 0.073175, 15.3446]
# 2021-11-05 [1636083600000, 0.073177, 0.073188, 0.073164, 0.073164, 11.8433]
# 2021-11-05 [1636083660000, 0.073163, 0.073172, 0.073156, 0.073158, 20.9377]
# 2021-11-05 [1636083720000, 0.073158, 0.073163, 0.073134, 0.073141, 10.6931]
# ...

# %%
# 얼굴인식 개꿀 잼

# %%
mUE9uTyifvYnQGm8znbM
51vhg2_a8m
